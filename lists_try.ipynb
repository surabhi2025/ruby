# %% [markdown]
# # Lists

# %%
x = [1,2,3,4,5]
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
for i in x:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
hi = ['a','b','c','d','e']

for i in hi:
    print(i)
# Out:
# a
# b
# c
# d
# e

# %%
range(len())
# Out:
# range(0, 5)

# %%
for i in range(0, len(hi), 2):
    print(i, hi[i])
    #print(hi[i])
# Out:
# 0 a
# 2 c
# 4 e

# %%
for i in range(len(hi)-1, -1, -1):
    print(hi[i])
# Out:
# e
# d
# c
# b
# a
